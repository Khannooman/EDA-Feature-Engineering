# %% [markdown]
# TIME SERIES DATA

# %%
# install data reader
# !pip install pandas-datareader

# %%
import pandas_datareader as pdr
from datetime import datetime

# %%
df_tcs = pdr.get_data_yahoo("TCS.NS")
df_tcs.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df_tcs = pdr.get_data_yahoo("TCS.NS")
#       2 df_tcs.head()
#
# File ~\anaconda3\lib\site-packages\pandas_datareader\data.py:80, in get_data_yahoo(*args, **kwargs)
#      79 def get_data_yahoo(*args, **kwargs):
# ---> 80     return YahooDailyReader(*args, **kwargs).read()
#
# File ~\anaconda3\lib\site-packages\pandas_datareader\base.py:253, in _DailyBaseReader.read(self)
#     251 # If a single symbol, (e.g., 'GOOG')
#     252 if isinstance(self.symbols, (string_types, int)):
# --> 253     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#     254 # Or multiple symbols, (e.g., ['GOOG', 'AAPL', 'MSFT'])
#     255 elif isinstance(self.symbols, DataFrame):
#
# ...

# %%
import pandas_datareader as pdr

# Define the ticker symbol, start date, and end date for the data
ticker = "TCS.NS"
start_date = '2010-01-01'
end_date = '2021-12-31'

# Retrieve the data from Yahoo Finance
data = pdr.get_data_yahoo(ticker, start=start_date, end=end_date)

# Print the first few rows of the data
data.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 9
#       6 end_date = '2021-12-31'
#       8 # Retrieve the data from Yahoo Finance
# ----> 9 data = pdr.get_data_yahoo(ticker, start=start_date, end=end_date)
#      11 # Print the first few rows of the data
#      12 data.head()
#
# File ~\anaconda3\lib\site-packages\pandas_datareader\data.py:80, in get_data_yahoo(*args, **kwargs)
#      79 def get_data_yahoo(*args, **kwargs):
# ---> 80     return YahooDailyReader(*args, **kwargs).read()
#
# File ~\anaconda3\lib\site-packages\pandas_datareader\base.py:253, in _DailyBaseReader.read(self)
#     251 # If a single symbol, (e.g., 'GOOG')
#     252 if isinstance(self.symbols, (string_types, int)):
# --> 253     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#     254 # Or multiple symbols, (e.g., ['GOOG', 'AAPL', 'MSFT'])
# ...

# %%
import yfinance as yf

data = yf.download(ticker, start=start_date, end=end_date)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 import yfinance as yf
#       3 data = yf.download(ticker, start=start_date, end=end_date)
#
# ModuleNotFoundError: No module named 'yfinance'

# %%
import pandas_datareader as pdr

# Define the ticker symbol, start date, and end date for the data
ticker = "TCS.NS"
start_date = '2010-01-01'
end_date = '2021-12-31'

# Retrieve the data from FRED
data = pdr.get_data_fred(ticker, start=start_date, end=end_date)
# Out:
# ---------------------------------------------------------------------------
# RemoteDataError                           Traceback (most recent call last)
# Cell In[16], line 9
#       6 end_date = '2021-12-31'
#       8 # Retrieve the data from FRED
# ----> 9 data = pdr.get_data_fred(ticker, start=start_date, end=end_date)
#
# File ~\anaconda3\lib\site-packages\pandas_datareader\data.py:72, in get_data_fred(*args, **kwargs)
#      71 def get_data_fred(*args, **kwargs):
# ---> 72     return FredReader(*args, **kwargs).read()
#
# File ~\anaconda3\lib\site-packages\pandas_datareader\fred.py:27, in FredReader.read(self)
#      18 """Read data
#      19
#      20 Returns
#    (...)
#      24     DataFrame is the outer join of the indicies of each series.
#      25 """
#      26 try:
# ---> 27     return self._read()
#      28 finally:
#      29     self.close()
#
# File ~\anaconda3\lib\site-packages\pandas_datareader\fred.py:62, in FredReader._read(self)
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize = (20,15))
df_tcs.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.figure(figsize = (15,10))
df_tcs["High"].plot()
plt.show()

# %%
plt.figure(figsize = (15,7))
df_tcs["High"].plot(xlim = ["2020-01-01","2022-12-14"])
plt.show()

# %%
plt.figure(figsize = (15,7))
df_tcs["High"].plot(xlim = ["2020-01-01","2022-12-14"],color = "red" , ls = "--")
plt.show()

# %%
plt.figure(figsize = (10,5))
df_tcs.loc["2020-01-01":"2022-12-13"]["Open"].plot()
plt.show()

# %%
# %matplotlib inline

# %%
df_tcs = df_tcs.reset_index()
df_tcs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1258 non-null   datetime64[ns]
#  1   High       1258 non-null   float64
#  2   Low        1258 non-null   float64
#  3   Open       1258 non-null   float64
#  4   Close      1258 non-null   float64
#  5   Volume     1258 non-null   float64
#  6   Adj Close  1258 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 68.9 KB

# %%
from datetime import datetime

# %%
datetime(2022,12,14)
# Out:
# datetime.datetime(2022, 12, 14, 0, 0)

# %%
datetime.now()
# Out:
# datetime.datetime(2023, 1, 24, 8, 4, 13, 73163)

# %%
date = datetime.now().date()

# %%
date.month
# Out:
# 1

# %%
date.year
# Out:
# 2023

# %%
date.day
# Out:
# 24

# %%
date.weekday()
# Out:
# 2

# %%
max(df_tcs['Date']).date().day
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 max(df_tcs['Date']).date().day
#
# NameError: name 'df_tcs' is not defined

# %%
df_tcs = df_tcs.set_index('Date',drop=True)
df_tcs.head()
# Out:
#             High   Low  Open  Close    Volume  Adj Close
# Date
# 2017-12-14  5.57  5.21  5.50   5.30  276900.0   4.954348
# 2017-12-15  5.46  5.26  5.30   5.34  297600.0   4.991739
# 2017-12-18  5.58  5.33  5.37   5.57   78200.0   5.206739
# 2017-12-19  5.57  5.30  5.56   5.35   90800.0   5.001087
# 2017-12-20  5.48  5.33  5.39   5.41   77300.0   5.057174

# %% [markdown]
# ### Time Resampling

# %%
# A means annualy
df_tcs.resample(rule = "A").min()
# Out:
#             High   Low  Open  Close    Volume  Adj Close
# Date
# 2017-12-31  5.05  4.73  4.98   4.74   47100.0   4.430870
# 2018-12-31  4.37  3.57  4.21   4.22   50100.0   3.944782
# 2019-12-31  3.76  3.57  3.70   3.66   99000.0   3.421304
# 2020-12-31  2.05  1.80  1.80   1.99   73800.0   1.869565
# 2021-12-31  9.83  9.23  9.54   9.52  205100.0   9.520000
# 2022-12-31  4.54  4.24  4.43   4.33  112400.0   4.330000

# %%
df_tcs.resample(rule = "A").max()["High"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tcs.resample(rule = "A").max()["Open"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df_tcs.resample(rule = "w").min()
# Out:
#             High   Low  Open  Close    Volume  Adj Close
# Date
# 2017-12-17  5.46  5.21  5.30   5.30  276900.0   4.954348
# 2017-12-24  5.45  5.30  5.35   5.35   47100.0   5.001087
# 2017-12-31  5.05  4.73  4.98   4.74  178000.0   4.430870
# 2018-01-07  4.94  4.72  4.79   4.85  205500.0   4.533696
# 2018-01-14  4.87  4.57  4.62   4.64   96400.0   4.337391
# ...          ...   ...   ...    ...       ...        ...
# 2022-11-20  4.63  4.43  4.49   4.50  500400.0   4.500000
# 2022-11-27  4.54  4.37  4.48   4.48  112400.0   4.480000
# 2022-12-04  4.68  4.58  4.59   4.62  202200.0   4.620000
# 2022-12-11  4.80  4.61  4.71   4.72  270700.0   4.720000
# 2022-12-18  5.03  4.80  4.99   4.84  299800.0   4.840000
#
# [262 rows x 6 columns]

# %%
df_tcs.resample(rule = "w").mean()
# Out:
#               High     Low   Open   Close    Volume  Adj Close
# Date
# 2017-12-17  5.5150  5.2350  5.400  5.3200  287250.0   4.973044
# 2017-12-24  5.5140  5.3300  5.410  5.4220   73320.0   5.068391
# 2017-12-31  5.2575  4.9200  5.185  5.0475  258025.0   4.718315
# 2018-01-07  5.0250  4.7675  4.905  4.9350  252500.0   4.613152
# 2018-01-14  4.9760  4.7080  4.838  4.8680  180600.0   4.550522
# ...            ...     ...    ...     ...       ...        ...
# 2022-11-20  4.8620  4.6020  4.746  4.6460  592400.0   4.646000
# 2022-11-27  4.7650  4.5775  4.635  4.7025  596500.0   4.702500
# 2022-12-04  4.7920  4.6420  4.684  4.7080  260520.0   4.708000
# 2022-12-11  4.9020  4.7040  4.770  4.8220  328040.0   4.822000
# 2022-12-18  5.0500  4.8100  4.995  4.8700  348650.0   4.870000
#
# [262 rows x 6 columns]

# %%
df_tcs.resample(rule = "m").mean()["Close"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tcs.resample(rule = "q").mean()
# Out:
#                  High        Low       Open      Close        Volume  \
# Date
# 2017-12-31   5.420909   5.163636   5.326364   5.267273  1.793818e+05
# 2018-03-31   5.140656   4.859344   5.005738   5.013934  2.252820e+05
# 2018-06-30   7.212969   6.886719   7.014531   7.063281  2.428578e+05
# 2018-09-30  10.174286   9.726032   9.933492   9.958254  3.804571e+05
# 2018-12-31   7.239365   6.852063   7.055556   7.003809  3.617714e+05
# 2019-03-31   6.680164   6.362623   6.480492   6.559016  3.132295e+05
# 2019-06-30   8.224444   7.907143   8.086984   8.056984  3.732286e+05
# 2019-09-30   5.571250   5.300938   5.466094   5.413281  2.998078e+05
# 2019-12-31   4.324063   4.124063   4.219375   4.225781  2.689203e+05
# 2020-03-31   3.822903   3.573548   3.722742   3.698065  2.651097e+05
# 2020-06-30   2.702063   2.442698   2.566825   2.572540  3.207635e+05
# 2020-09-30   4.506406   4.123594   4.262656   4.287500  5.734344e+05
# ...

# %%
df_tcs["High"].rolling(7).mean()
# Out:
# Date
# 2017-12-14         NaN
# 2017-12-15         NaN
# 2017-12-18         NaN
# 2017-12-19         NaN
# 2017-12-20         NaN
#                 ...
# 2022-12-07    4.805714
# 2022-12-08    4.842857
# 2022-12-09    4.884286
# 2022-12-12    4.904286
# 2022-12-13    4.944286
# Name: High, Length: 1258, dtype: float64

# %%
df_tcs.tail()
# Out:
#             High   Low  Open  Close    Volume  Adj Close
# Date
# 2022-12-07  4.80  4.71  4.72   4.78  305600.0       4.78
# 2022-12-08  4.94  4.73  4.80   4.85  270700.0       4.85
# 2022-12-09  5.09  4.85  4.85   5.01  417100.0       5.01
# 2022-12-12  5.03  4.80  4.99   4.84  397500.0       4.84
# 2022-12-13  5.07  4.82  5.00   4.90  299800.0       4.90

# %%
roling_7 = df_tcs[["Close"]]
roling_7["7_day_rolling_avg"] = roling_7["Close"].rolling(7).mean()
roling_7
# Out:
# C:\Users\NOOMAN KHAN\AppData\Local\Temp\ipykernel_24016\3694799898.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   roling_7["7_day_rolling_avg"] = roling_7["Close"].rolling(7).mean()
#             Close  7_day_rolling_avg
# Date
# 2017-12-14   5.30                NaN
# 2017-12-15   5.34                NaN
# 2017-12-18   5.57                NaN
# 2017-12-19   5.35                NaN
# 2017-12-20   5.41                NaN
# ...           ...                ...
# 2022-12-07   4.78           4.738571
# 2022-12-08   4.85           4.770000
# 2022-12-09   5.01           4.807143
# 2022-12-12   4.84           4.811429
# 2022-12-13   4.90           4.835714
#
# [1258 rows x 2 columns]

# %%
roling_7.head(20)
# Out:
#             Close  7_day_rolling_avg
# Date
# 2017-12-14   5.30                NaN
# 2017-12-15   5.34                NaN
# 2017-12-18   5.57                NaN
# 2017-12-19   5.35                NaN
# 2017-12-20   5.41                NaN
# 2017-12-21   5.41                NaN
# 2017-12-22   5.37           5.392857
# 2017-12-26   5.42           5.410000
# 2017-12-27   4.96           5.355714
# 2017-12-28   5.07           5.284286
# 2017-12-29   4.74           5.197143
# 2018-01-02   5.08           5.150000
# 2018-01-03   4.85           5.070000
# 2018-01-04   4.96           5.011429
# 2018-01-05   4.85           4.930000
# 2018-01-08   4.88           4.918571
# 2018-01-09   4.64           4.857143
# 2018-01-10   4.93           4.884286
# 2018-01-11   4.99           4.871428
# 2018-01-12   4.90           4.878571

# %%
roling_7.plot(figsize = (10,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# simple moving average
df_tcs['High:10 day rolling avg'] = df_tcs["High"].rolling(window = 10 , min_periods = 1).mean()

# %%
df_tcs['High:20 day rolling avg'] = df_tcs["High"].rolling(window = 20 , min_periods = 1).mean()
df_tcs['High:30 day rolling avg'] = df_tcs["High"].rolling(window = 30 , min_periods = 1).mean()

# %%
df_tcs[['High','High:10 day rolling avg','High:20 day rolling avg','High:30 day rolling avg']].plot(figsize =
                                                                                            (15,7),xlim = ["2020-01-01","2022-12-13"])
plt.show()

# %%
df_tcs[['High','High:10 day rolling avg']].plot(figsize =
                                                        (15,7),xlim = ["2020-01-01","2022-12-13"])
plt.show()

# %%
# Expanding
# Commulative Average
df_tcs["Open"].expanding().mean().plot(figsize = (12,7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Exponential moving average
# ### EMA
# What Is an Exponential Moving Average (EMA)?
#
# An exponential moving average (EMA) is a type of moving average (MA) that places a greater weight and significance on the most recent data points. The exponential moving average is also referred to as the exponentially weighted moving average. An exponentially weighted moving average reacts more significantly to recent price changes than a simple moving average simple moving average (SMA), which applies an equal weight to all observations in the period.

# %% [markdown]
# KEY TAKEAWAYS
#
# The EMA is a moving average that places a greater weight and significance on the most recent data points.
#
# Like all moving averages, this technical indicator is used to produce buy and sell signals based on crossovers and divergences from the historical average.
#
# Traders often use several different EMA lengths, such as 10-day, 50-day, and 200-day moving averages.

# %%
df_tcs["EWM_0.1"] = df_tcs["Close"].ewm(alpha = 0.1,adjust = False).mean()

# %%
df_tcs[["Close","EWM_0.1"]].plot(figsize = (12,7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tcs["EWM_0.3"] = df_tcs["Close"].ewm(alpha = 0.3,adjust = False).mean()
df_tcs[["Close","EWM_0.1","EWM_0.3"]].plot(figsize = (12,7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
pd.read_csv("C:/Users/NOOMAN KHAN/Downloads/stock_nifty50.csv")
# Out:
#        Unnamed: 0        Date    Symbol Series  Prev Close    Open    High  \
# 0               0  2018-12-12  ADANIENT     EQ      151.90  152.80  157.00
# 1               1  2018-12-13  ADANIENT     EQ      156.10  156.00  158.60
# 2               2  2018-12-14  ADANIENT     EQ      156.00  156.00  157.90
# 3               3  2018-12-17  ADANIENT     EQ      157.10  157.10  158.90
# 4               4  2018-12-18  ADANIENT     EQ      157.95  157.70  159.75
# ...           ...         ...       ...    ...         ...     ...     ...
# 47611       47611  2022-12-06     WIPRO     EQ      412.35  410.50  412.60
# 47612       47612  2022-12-07     WIPRO     EQ      411.35  409.00  409.50
# 47613       47613  2022-12-08     WIPRO     EQ      406.30  407.25  408.00
# 47614       47614  2022-12-09     WIPRO     EQ      403.70  406.00  406.00
# 47615       47615  2022-12-12     WIPRO     EQ      394.05  392.90  397.50
#
# ...
